# %%
# test cheetsheet

import json
import datetime
import pandas as pd
import numpy as np
import time
import csv
import re
import os
import schedule


# name = input(“Hi! What’s your name? “)

# -----iterate over list of dictionaris 

list_of_dic = [{"USER_ID": 1, "amount": 30, "items": 15}, {"USER_ID": 2, "amount": 10, "items": 1}]
  for dic in new_data:
        if all (k in dic for k in ("USER_ID","amount","items")): 
            if dic.get('USER_ID') in historical_data.keys():
                  old_user_dic = historical_data.get(dic.get('USER_ID'))


# ------try except schema 

my_dict = {“a”:1, “b”:2, “c”:3}
try:
    value = my_dict[“d”]
except IndexError:
    print(“This index does not exist!”)
except KeyError:
    print(“This key is not in the dictionary!”)

# -----הfiverr question :

error_ctr = 0
start_date = date.today() - timedelta(30)
end_date = date.today()

def daterange(start_date, end_date):
    for n in range(int((end_date - start_date).days)):
        yield start_date + timedelta(n)

for single_date in daterange(start_date, end_date):
    try:
        query = " SELECT id FROM  SPL WHERE date =  {} ".format(single_date)
        df = run_query(query)
        df.to_csv('path to save')
        df.to_json('path to save')
        send_email(recipients , csv_path)
        print(query)
        # print(single_date.strftime("%Y%m%d"))


    except:
        error_ctr += 1

# ------  behalf questions :

# adds to given date N months
from datetime import datetime, timedelta
from dateutil.relativedelta import *

date = datetime.now()
print(date)
date = date + relativedelta(months=+6)
print(date)

# counts the number of accurances of a key in a list of dictionaries 
from collections import Counter

data = {1: {"LTV_AVG": 10, "LTV_ITEMS": 100}, 7: {"LTV_AVG": 4.5, "LTV_ITEMS": 2}}
 
signs = Counter(k[0] for k in data if k.get(0))
for sign, count in signs.most_common():
     print(sign, count)


# return all distinct values of a given key in dic

lis = [{"abc":"movies"}, {"abc": "sports"}, {"abc": "music"}, {"xyz": "music"}, {"pqr":"music"}, {"pqr":"movies"},{"pqr":"sports"}, {"pqr":"news"}, {"pqr":"sports"}]
s = set( val for dic in lis for val in dic.values())
print(s )

# ---- regex question 

# import re

def fun(s):
  pattern = re.compile("^[\\w-]+@[0-9a-zA-Z]+\\.[a-z]{1,3}$")
  return pattern.match(s)
       
def filter_mail(emails):
    return list(filter(fun, emails))

if __name__ == '__main__':
    n = int(input())
    emails = []
    for _ in range(n):
        emails.append(input())

filtered_emails = filter_mail(emails)
filtered_emails.sort()
print(filtered_emails)

# --- json --- #

# json to dictionary :

person = '{"name": "Bob", "languages": ["English", "Fench"]}'
person_dict = json.loads(person)
print( person_dict)

# read json file to dictionary

with open('path_to_file/person.json') as f:
  data = json.load(f)

print(data)

# convert dictionary to json :

person_dict = {'name': 'Bob',
'age': 12,
'children': None
}
person_json = json.dumps(person_dict)

print(person_json)

# writing json to a file :

person_dict = {"name": "Bob",
"languages": ["English", "Fench"],
"married": True,
"age": 32
}

with open('person.txt', 'w') as json_file:
  json.dump(person_dict, json_file)

# --- csv --- #

# read csv file using csv.reader()
with open('people.csv', 'r') as file:
    reader = csv.reader(file)
    for row in reader:
        print(row)

# write csv file using csv.writer()

csv_rowlist = [["SN", "Movie", "Protagonist"], [1, "Lord of the Rings", "Frodo Baggins"],
               [2, "Harry Potter", "Harry Potter"]]
with open('protagonist.csv', 'w') as file:
    writer = csv.writer(file)
    writer.writerows(csv_rowlist)

# read csv file to dictionary with csv.DictReader()

with open("people.csv", 'r') as file:
    csv_file = csv.DictReader(file)
    for row in csv_file:
        print(dict(row))

# write csv file from dictionary to file with csv.DictWriter()

with open('players.csv', 'w', newline='') as file:
    fieldnames = ['player_name', 'fide_rating']
    writer = csv.DictWriter(file, fieldnames=fieldnames)

    writer.writeheader()
    writer.writerow({'player_name': 'Magnus Carlsen', 'fide_rating': 2870})
    writer.writerow({'player_name': 'Fabiano Caruana', 'fide_rating': 2822})
    writer.writerow({'player_name': 'Ding Liren', 'fide_rating': 2801})

#  read and write csv with pandas 

pd.read_csv("people.csv")

df = pd.DataFrame([['Jack', 24], ['Rose', 22]], columns = ['Name', 'Age'])
df.to_csv('person.csv')



def some_fun():
    print("test")

if __name__ == '__main__':
    some_fun()
    # print("eran")
# Out:
# test

# %%
import json
import datetime
import pandas as pd
import numpy as np
import time
import csv
import re
import os
import schedule


data = """{"1.7613261750023548": {"interview": "Negro", "#DE": "21234", "#DECumsum": "21234", "#DERelPos": "0.22", "#DERelSize": "0.22", "#PurcDE": "374", "#PurcDECumsum": "374", "#PurcDERelPos": "0.08", "#PurcDERelSize": "0.08", "#URV_DE": "12577", "#URV_DECumsum": "12577", "#URV_DERelPos": "0.45", "#URV_DERelSize": "0.45", "#URV_PurcDE": "271", "#URV_PurcDECumsum": "271", "#URV_PurcDERelPos": "0.21", "#URV_PurcDERelSize": "0.21", "actPoP": "0.018000000000000002"}, "2.48496993987976": {"#DE": "9980", "#DECumsum": "31214", "#DERelPos": "0.32", "#DERelSize": "0.1", "#PurcDE": "248", "#PurcDECumsum": "622", "#PurcDERelPos": "0.14", "interview": "Ampl","#PurcDERelSize": "0.05", "#URV_DE": "3947", "#URV_DECumsum": "16524", "#URV_DERelPos": "0.59", "#URV_DERelSize": "0.14", "#URV_PurcDE": "142", "#URV_PurcDECumsum": "413", "#URV_PurcDERelPos": "0.32", "#URV_PurcDERelSize": "0.11", "actPoP": "0.025"}, "2.927321668909825": { "#DE": "2972", "#DECumsum": "34186", "#DERelPos": "0.35", "interview": "Mango", "#DERelSize": "0.03", "#PurcDE": "87", "#PurcDECumsum": "709", "#PurcDERelPos": "0.16", "#PurcDERelSize": "0.02", "#URV_DE": "552", "#URV_DECumsum": "17076", "#URV_DERelPos": "0.61", "#URV_DERelSize": "0.02", "#URV_PurcDE": "46", "#URV_PurcDECumsum": "459", "#URV_PurcDERelPos": "0.35", "#URV_PurcDERelSize": "0.04", "actPoP": "0.028999999999999998"}, "3.7423148890670954": {"interview": "Oracle", "#DE": "7482", "#DECumsum": "41668", "#DERelPos": "0.43", "#DERelSize": "0.08", "#PurcDE": "280", "#PurcDECumsum": "989", "#PurcDERelPos": "0.22", "#PurcDERelSize": "0.06", "#URV_DE": "1396", "#URV_DECumsum": "18472", "#URV_DERelPos": "0.66", "#URV_DERelSize": "0.05", "#URV_PurcDE": "72", "#URV_PurcDECumsum": "531", "#URV_PurcDERelPos": "0.41", "#URV_PurcDERelSize": "0.06", "actPoP": "0.037000000000000005"}, "14.776409591704473": {"#DE": "3086", "#DECumsum": "97683", "#DERelPos": "1.0", "#DERelSize": "0.03", "#PurcDE": "456", "interview": "Goodies", "#PurcDECumsum": "-1", "#PurcDERelPos": "1.0", "#PurcDERelSize": "0.1", "#URV_DE": "191", "#URV_DECumsum": "28161", "#URV_DERelPos": "1.0", "#URV_DERelSize": "0.01", "#URV_PurcDE": "60", "#URV_PurcDECumsum": "1294", "#URV_PurcDERelPos": "1.0", "#URV_PurcDERelSize": "0.05", "actPoP": "0.14800000000000002"}, "4.060043732639914": {"interview": "Orientalis", "#DE": "16921", "#DECumsum": "58589", "#DERelPos": "0.6", "#DERelSize": "0.17", "#PurcDE": "687", "#PurcDECumsum": "1676", "#PurcDERelPos": "0.37", "#PurcDERelSize": "0.15", "#URV_DE": "4695", "#URV_DECumsum": "23167", "#URV_DERelPos": "0.82", "#URV_DERelSize": "0.17", "#URV_PurcDE": "226", "#URV_PurcDECumsum": "757", "#URV_PurcDERelPos": "0.59", "#URV_PurcDERelSize": "0.17", "actPoP": "0.040999999999999995"}, "11.402623612512611": {"#DE": "2973", "#DECumsum": "94597", "#DERelPos": "0.97", "#DERelSize": "0.03", "#PurcDE": "339", "#PurcDECumsum": "-1", "#PurcDERelPos": "0.9", "#PurcDERelSize": "0.07", "#URV_DE": "239", "#URV_DECumsum": "27970", "#URV_DERelPos": "0.99", "#URV_DERelSize": "0.01", "interview": "Orbit", "#URV_PurcDE": "22", "#URV_PurcDECumsum": "1234", "#URV_PurcDERelPos": "0.95", "#URV_PurcDERelSize": "0.02", "actPoP": "0.114"}}"""


if __name__ == '__main__':
    print("start")


    dic = json.loads(data)
    for key,val in dic.items() :
        print(val.get('interview'))
    
    # print(dic)
# Out:
# start
# 1.7613261750023548
# {'interview': 'Negro', '#DE': '21234', '#DECumsum': '21234', '#DERelPos': '0.22', '#DERelSize': '0.22', '#PurcDE': '374', '#PurcDECumsum': '374', '#PurcDERelPos': '0.08', '#PurcDERelSize': '0.08', '#URV_DE': '12577', '#URV_DECumsum': '12577', '#URV_DERelPos': '0.45', '#URV_DERelSize': '0.45', '#URV_PurcDE': '271', '#URV_PurcDECumsum': '271', '#URV_PurcDERelPos': '0.21', '#URV_PurcDERelSize': '0.21', 'actPoP': '0.018000000000000002'}
# 2.48496993987976
# {'#DE': '9980', '#DECumsum': '31214', '#DERelPos': '0.32', '#DERelSize': '0.1', '#PurcDE': '248', '#PurcDECumsum': '622', '#PurcDERelPos': '0.14', 'interview': 'Ampl', '#PurcDERelSize': '0.05', '#URV_DE': '3947', '#URV_DECumsum': '16524', '#URV_DERelPos': '0.59', '#URV_DERelSize': '0.14', '#URV_PurcDE': '142', '#URV_PurcDECumsum': '413', '#URV_PurcDERelPos': '0.32', '#URV_PurcDERelSize': '0.11', 'actPoP': '0.025'}
# 2.927321668909825
# ...
